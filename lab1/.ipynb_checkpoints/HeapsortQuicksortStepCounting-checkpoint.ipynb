# %%
import numpy as np
import time
import matplotlib.pyplot as plt


def heapify(arr, n, i):
    # current as largest, calc. index of left and right child nodes
    largest = i

    left = 2 * i + 1
    right = 2 * i + 2

    # if the left child exists &  greater than the current largest
    if left < n and arr[i] < arr[left]:
        largest = left

    # if the right child exists & greater than the current largest
    if right < n and arr[largest] < arr[right]:
        largest = right

    # If the largest is not the current node, swap the values and recursively heapify
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def heapsort(arr):
    n = len(arr)
    # heapifying each non-leaf node in reverse order
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    # extract one by one from the heap
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)
    return arr  #   sorted array


"""
The input array to be sorted. Returns: sorted array.
    """
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0] #getting pivot as 1st el.
        # Divide into two: elements less than or equal to the pivot (less)
        # and elements greater than the pivot (greater)
        less = [x for x in arr[1:] if x <= pivot]
        greater = [x for x in arr[1:] if x > pivot]
        return quicksort(less) + [pivot] + quicksort(greater)


"""Getting start time, sort copy of array, get end time.
Calculate exec. time + length of sorted array """        
def measure_time_and_steps(sort_function, array):
    start = time.time()
    sorted_array = sort_function(array.copy())
    end = time.time()
    execution_time = end - start
    return execution_time, len(sorted_array)

input_sizes = [10, 50, 100, 500, 1000, 5000, 10000]
steps_heapsort = []
steps_quicksort = []

for size in input_sizes:
    # sorted array (asc)
    sorted_array = np.arange(size)
    # Shuffle/random arr
    np.random.shuffle(sorted_array)

    # Time and steps for heapsort on a random array
    time_heapsort_random, steps_heapsort_random = measure_time_and_steps(heapsort, sorted_array.copy())
    steps_heapsort.append(steps_heapsort_random)

    # Time and steps for quicksort on a random array
    time_quicksort_random, steps_quicksort_random = measure_time_and_steps(quicksort, sorted_array.copy())
    steps_quicksort.append(steps_quicksort_random)

    # Time and steps for heapsort on a sorted array (best-case)
    time_heapsort_best, steps_heapsort_best = measure_time_and_steps(heapsort, np.arange(size))
    steps_heapsort_best = np.full_like(input_sizes, steps_heapsort_best)  # Repeat the value for all input sizes
    
    # Time and steps for quicksort on a sorted array (best-case)
    time_quicksort_best, steps_quicksort_best = measure_time_and_steps(quicksort, np.arange(size))
    steps_quicksort_best = np.full_like(input_sizes, steps_quicksort_best)  # Repeat the value for all input sizes
    

    # Time and steps for heapsort on a reversed array (worst-case)
    time_heapsort_worst, steps_heapsort_worst = measure_time_and_steps(heapsort, np.arange(size)[::-1])
    steps_heapsort_worst = np.full_like(input_sizes, steps_heapsort_worst)  # Repeat the value for all input sizes
    
    # Time and steps for quicksort on a reversed array (worst-case)
    time_quicksort_worst, steps_quicksort_worst = measure_time_and_steps(quicksort, np.arange(size)[::-1])
    steps_quicksort_worst = np.full_like(input_sizes, steps_quicksort_worst)  # Repeat the value for all input sizes


    # Print results
    print(f"Size {size}:"
          f"\n  Heapsort time (random) = {time_heapsort_random}, Quicksort time (random) = {time_quicksort_random}"
          f"\n  Heapsort steps (random) = {steps_heapsort_random}, Quicksort steps (random) = {steps_quicksort_random}"
          f"\n  Heapsort time (best) = {time_heapsort_best}, Quicksort time (best) = {time_quicksort_best}"
          f"\n  Heapsort steps (best) = {steps_heapsort_best}, Quicksort steps (best) = {steps_quicksort_best}"
          f"\n  Heapsort time (worst) = {time_heapsort_worst}, Quicksort time (worst) = {time_quicksort_worst}"
          f"\n  Heapsort steps (worst) = {steps_heapsort_worst}, Quicksort steps (worst) = {steps_quicksort_worst}\n")




# Plotting combined results with logarithmic scale on y-axis
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, steps_heapsort, label='Heapsort (Random)')
plt.plot(input_sizes, steps_quicksort, label='Quicksort (Random)')

plt.plot(input_sizes, steps_heapsort_best, label='Heapsort (Best-case)')
plt.plot(input_sizes, steps_quicksort_best, label='Quicksort (Best-case)')

plt.plot(input_sizes, steps_heapsort_worst, label='Heapsort (Worst-case)')
plt.plot(input_sizes, steps_quicksort_worst, label='Quicksort (Worst-case)')

plt.xlabel('Input Size (n)')
plt.ylabel('Number of Steps')
plt.title('Comparison of Heapsort and Quicksort')
plt.legend()
plt.yscale('log')  # Set logarithmic scale on the y-axis
plt.show()
# Out:
# Size 10:
#   Heapsort time (random) = 0.00018024444580078125, Quicksort time (random) = 3.910064697265625e-05
#   Heapsort steps (random) = 10, Quicksort steps (random) = 10
#   Heapsort time (best) = 2.1696090698242188e-05, Quicksort time (best) = 1.7642974853515625e-05
#   Heapsort steps (best) = [10 10 10 10 10 10 10], Quicksort steps (best) = [10 10 10 10 10 10 10]
#   Heapsort time (worst) = 7.104873657226562e-05, Quicksort time (worst) = 2.86102294921875e-05
#   Heapsort steps (worst) = [10 10 10 10 10 10 10], Quicksort steps (worst) = [10 10 10 10 10 10 10]
#
# Size 50:
#   Heapsort time (random) = 0.00012040138244628906, Quicksort time (random) = 6.389617919921875e-05
#   Heapsort steps (random) = 50, Quicksort steps (random) = 50
#   Heapsort time (best) = 0.00013828277587890625, Quicksort time (best) = 0.0001857280731201172
#   Heapsort steps (best) = [50 50 50 50 50 50 50], Quicksort steps (best) = [50 50 50 50 50 50 50]
#   Heapsort time (worst) = 0.00011444091796875, Quicksort time (worst) = 0.0001246929168701172
#   Heapsort steps (worst) = [50 50 50 50 50 50 50], Quicksort steps (worst) = [50 50 50 50 50 50 50]
#
# Size 100:
#   Heapsort time (random) = 0.0002906322479248047, Quicksort time (random) = 0.00011348724365234375
#   Heapsort steps (random) = 100, Quicksort steps (random) = 100
#   Heapsort time (best) = 0.0003192424774169922, Quicksort time (best) = 0.0005354881286621094
#   Heapsort steps (best) = [100 100 100 100 100 100 100], Quicksort steps (best) = [100 100 100 100 100 100 100]
#   Heapsort time (worst) = 0.00032067298889160156, Quicksort time (worst) = 0.0004181861877441406
#   Heapsort steps (worst) = [100 100 100 100 100 100 100], Quicksort steps (worst) = [100 100 100 100 100 100 100]
#
# Size 500:
#   Heapsort time (random) = 0.002065896987915039, Quicksort time (random) = 0.0024576187133789062
#   Heapsort steps (random) = 500, Quicksort steps (random) = 500
#   Heapsort time (best) = 0.0027501583099365234, Quicksort time (best) = 0.01390218734741211
#   Heapsort steps (best) = [500 500 500 500 500 500 500], Quicksort steps (best) = [500 500 500 500 500 500 500]
#   Heapsort time (worst) = 0.0023047924041748047, Quicksort time (worst) = 0.012378454208374023
#   Heapsort steps (worst) = [500 500 500 500 500 500 500], Quicksort steps (worst) = [500 500 500 500 500 500 500]
#
# Size 1000:
#   Heapsort time (random) = 0.004963874816894531, Quicksort time (random) = 0.0014405250549316406
#   Heapsort steps (random) = 1000, Quicksort steps (random) = 1000
#   Heapsort time (best) = 0.0053424835205078125, Quicksort time (best) = 0.032749176025390625
#   Heapsort steps (best) = [1000 1000 1000 1000 1000 1000 1000], Quicksort steps (best) = [1000 1000 1000 1000 1000 1000 1000]
#   Heapsort time (worst) = 0.00445246696472168, Quicksort time (worst) = 0.03206586837768555
#   Heapsort steps (worst) = [1000 1000 1000 1000 1000 1000 1000], Quicksort steps (worst) = [1000 1000 1000 1000 1000 1000 1000]
#
# Size 5000:
#   Heapsort time (random) = 0.031612396240234375, Quicksort time (random) = 0.007514238357543945
#   Heapsort steps (random) = 5000, Quicksort steps (random) = 5000
#   Heapsort time (best) = 0.03478264808654785, Quicksort time (best) = 0.9668357372283936
#   Heapsort steps (best) = [5000 5000 5000 5000 5000 5000 5000], Quicksort steps (best) = [5000 5000 5000 5000 5000 5000 5000]
#   Heapsort time (worst) = 0.03150033950805664, Quicksort time (worst) = 0.8681721687316895
#   Heapsort steps (worst) = [5000 5000 5000 5000 5000 5000 5000], Quicksort steps (worst) = [5000 5000 5000 5000 5000 5000 5000]
#
# Size 10000:
#   Heapsort time (random) = 0.07114171981811523, Quicksort time (random) = 0.01714038848876953
#   Heapsort steps (random) = 10000, Quicksort steps (random) = 10000
#   Heapsort time (best) = 0.07812118530273438, Quicksort time (best) = 3.4408745765686035
#   Heapsort steps (best) = [10000 10000 10000 10000 10000 10000 10000], Quicksort steps (best) = [10000 10000 10000 10000 10000 10000 10000]
#   Heapsort time (worst) = 0.06747055053710938, Quicksort time (worst) = 3.496044397354126
#   Heapsort steps (worst) = [10000 10000 10000 10000 10000 10000 10000], Quicksort steps (worst) = [10000 10000 10000 10000 10000 10000 10000]

# %%
input_sizes = [10, 50, 100, 500, 1000, 5000, 10000]
steps_heapsort = []
steps_quicksort = []
steps_heapsort_best = []  # Separate lists for best-case steps
steps_quicksort_best = []  # Separate lists for best-case steps
steps_heapsort_worst = []  # Separate lists for worst-case steps
steps_quicksort_worst = []  # Separate lists for worst-case steps

for size in input_sizes:
    # sorted array (asc)
    sorted_array = np.arange(size)
    # Shuffle/random arr
    np.random.shuffle(sorted_array)

    # Time and steps for heapsort on a random array
    time_heapsort_random, steps_heapsort_random = measure_time_and_steps(heapsort, sorted_array.copy())
    steps_heapsort.append(steps_heapsort_random)

    # Time and steps for quicksort on a random array
    time_quicksort_random, steps_quicksort_random = measure_time_and_steps(quicksort, sorted_array.copy())
    steps_quicksort.append(steps_quicksort_random)

    # Time and steps for heapsort on a sorted array (best-case)
    time_heapsort_best, steps_heapsort_best_current = measure_time_and_steps(heapsort, np.arange(size))
    steps_heapsort_best.append(steps_heapsort_best_current)

    # Time and steps for quicksort on a sorted array (best-case)
    time_quicksort_best, steps_quicksort_best_current = measure_time_and_steps(quicksort, np.arange(size))
    steps_quicksort_best.append(steps_quicksort_best_current)

    # Time and steps for heapsort on a reversed array (worst-case)
    time_heapsort_worst, steps_heapsort_worst_current = measure_time_and_steps(heapsort, np.arange(size)[::-1])
    steps_heapsort_worst.append(steps_heapsort_worst_current)

    # Time and steps for quicksort on a reversed array (worst-case)
    time_quicksort_worst, steps_quicksort_worst_current = measure_time_and_steps(quicksort, np.arange(size)[::-1])
    steps_quicksort_worst.append(steps_quicksort_worst_current)

    # Print results
    print(f"Size {size}:"
          f"\n  Heapsort time (random) = {time_heapsort_random}, Quicksort time (random) = {time_quicksort_random}"
          f"\n  Heapsort steps (random) = {steps_heapsort_random}, Quicksort steps (random) = {steps_quicksort_random}"
          f"\n  Heapsort time (best) = {time_heapsort_best}, Quicksort time (best) = {time_quicksort_best}"
          f"\n  Heapsort steps (best) = {steps_heapsort_best_current}, Quicksort steps (best) = {steps_quicksort_best_current}"
          f"\n  Heapsort time (worst) = {time_heapsort_worst}, Quicksort time (worst) = {time_quicksort_worst}"
          f"\n  Heapsort steps (worst) = {steps_heapsort_worst_current}, Quicksort steps (worst) = {steps_quicksort_worst_current}\n")


"""Plotting combined results with logarithmic scale on y-axis"""
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, steps_heapsort, label='Heapsort (Random)')
plt.plot(input_sizes, steps_quicksort, label='Quicksort (Random)')
plt.plot(input_sizes, steps_heapsort_best, label='Heapsort (Best-case)', linestyle='--', marker='o')
plt.plot(input_sizes, steps_quicksort_best, label='Quicksort (Best-case)', linestyle='--', marker='o')
plt.plot(input_sizes, steps_heapsort_worst, label='Heapsort (Worst-case)', linestyle='--', marker='o')
plt.plot(input_sizes, steps_quicksort_worst, label='Quicksort (Worst-case)', linestyle='--', marker='o')
plt.xlabel('Input Size (n)')
plt.ylabel('Number of Steps')
plt.title('Comparison of Heapsort and Quicksort')
plt.legend()
plt.yscale('log')  # Set logarithmic scale on the y-axis
plt.show()
# Out:
# Size 10:
#   Heapsort time (random) = 6.556510925292969e-05, Quicksort time (random) = 9.465217590332031e-05
#   Heapsort steps (random) = 10, Quicksort steps (random) = 10
#   Heapsort time (best) = 7.963180541992188e-05, Quicksort time (best) = 0.00035762786865234375
#   Heapsort steps (best) = 10, Quicksort steps (best) = 10
#   Heapsort time (worst) = 0.0006206035614013672, Quicksort time (worst) = 6.67572021484375e-05
#   Heapsort steps (worst) = 10, Quicksort steps (worst) = 10
#
# Size 100:
#   Heapsort time (random) = 0.0007665157318115234, Quicksort time (random) = 0.00034928321838378906
#   Heapsort steps (random) = 100, Quicksort steps (random) = 100
#   Heapsort time (best) = 0.0007238388061523438, Quicksort time (best) = 0.0008196830749511719
#   Heapsort steps (best) = 100, Quicksort steps (best) = 100
#   Heapsort time (worst) = 0.0004429817199707031, Quicksort time (worst) = 0.0009424686431884766
#   Heapsort steps (worst) = 100, Quicksort steps (worst) = 100
#
# Size 1000:
#   Heapsort time (random) = 0.005866527557373047, Quicksort time (random) = 0.002588510513305664
#   Heapsort steps (random) = 1000, Quicksort steps (random) = 1000
#   Heapsort time (best) = 0.010481595993041992, Quicksort time (best) = 0.04224228858947754
#   Heapsort steps (best) = 1000, Quicksort steps (best) = 1000
#   Heapsort time (worst) = 0.004500150680541992, Quicksort time (worst) = 0.03250002861022949
#   Heapsort steps (worst) = 1000, Quicksort steps (worst) = 1000
#
# Size 10000:
#   Heapsort time (random) = 0.07181501388549805, Quicksort time (random) = 0.0157928466796875
#   Heapsort steps (random) = 10000, Quicksort steps (random) = 10000
#   Heapsort time (best) = 0.07466650009155273, Quicksort time (best) = 3.5735645294189453
#   Heapsort steps (best) = 10000, Quicksort steps (best) = 10000
#   Heapsort time (worst) = 0.061974525451660156, Quicksort time (worst) = 3.558321714401245
#   Heapsort steps (worst) = 10000, Quicksort steps (worst) = 10000
